# %%
import pandas as pd
df = pd.read_csv("D:\Customer-Intelligence-Growth-Analytics/data/processed/telco_customer_clean.csv")

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])

numeric_df.head()
# Out:
#    Count  Zip Code   Latitude   Longitude  Tenure Months  Monthly Charges  \
# 0      1     90003  33.964131 -118.272783              2            53.85
# 1      1     90005  34.059281 -118.307420              2            70.70
# 2      1     90006  34.048013 -118.293953              8            99.65
# 3      1     90010  34.062125 -118.315709             28           104.80
# 4      1     90015  34.039224 -118.266293             49           103.70
#
#    Total Charges  Churn Value  Churn Score  CLTV
# 0         108.15            1           86  3239
# 1         151.65            1           67  2701
# 2         820.50            1           86  5372
# 3        3046.05            1           84  5003
# 4        5036.30            1           89  5340

# %%
corr = numeric_df.corr()

corr
# Out:
#                  Count  Zip Code  Latitude  Longitude  Tenure Months  \
# Count              NaN       NaN       NaN        NaN            NaN
# Zip Code           NaN  1.000000  0.895743  -0.784271       0.001041
# Latitude           NaN  0.895743  1.000000  -0.876779      -0.001631
# Longitude          NaN -0.784271 -0.876779   1.000000      -0.001678
# Tenure Months      NaN  0.001041 -0.001631  -0.001678       1.000000
# Monthly Charges    NaN -0.004596 -0.019899   0.024098       0.247900
# Total Charges      NaN -0.000884 -0.009944   0.008876       0.826178
# Churn Value        NaN  0.003346 -0.003384   0.004594      -0.352229
# Churn Score        NaN -0.002769 -0.007684   0.004260      -0.224987
# CLTV               NaN -0.003562  0.000886   0.000485       0.396406
#
#                  Monthly Charges  Total Charges  Churn Value  Churn Score  \
# Count                        NaN            NaN          NaN          NaN
# Zip Code               -0.004596      -0.000884     0.003346    -0.002769
# Latitude               -0.019899      -0.009944    -0.003384    -0.007684
# Longitude               0.024098       0.008876     0.004594     0.004260
# Tenure Months           0.247900       0.826178    -0.352229    -0.224987
# Monthly Charges         1.000000       0.651174     0.193356     0.133754
# Total Charges           0.651174       1.000000    -0.198324    -0.123410
# Churn Value             0.193356      -0.198324     1.000000     0.664897
# Churn Score             0.133754      -0.123410     0.664897     1.000000
# CLTV                    0.098693       0.342091    -0.127463    -0.079782
#
#                      CLTV
# Count                 NaN
# Zip Code        -0.003562
# Latitude         0.000886
# Longitude        0.000485
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Total Charges    0.342091
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix")

plt.show()

# %%
monthly = (
    df.groupby("Churn Label")
      ["Monthly Charges"]
      .mean()
      .reset_index()
)

monthly
# Out:
#   Churn Label  Monthly Charges
# 0          No        61.265124
# 1         Yes        74.441332

# %%
tenure = (
    df.groupby("Churn Label")
      ["Tenure Months"]
      .mean()
      .reset_index()
)

tenure
# Out:
#   Churn Label  Tenure Months
# 0          No      37.569965
# 1         Yes      17.979133

# %%
cltv = (
    df.groupby("Churn Label")
      ["CLTV"]
      .mean()
      .reset_index()
)

cltv
# Out:
#   Churn Label         CLTV
# 0          No  4490.921337
# 1         Yes  4149.414660

# %%
score = (
    df.groupby("Churn Label")
      ["Churn Score"]
      .mean()
      .reset_index()
)

score
# Out:
#   Churn Label  Churn Score
# 0          No    50.098183
# 1         Yes    82.510433

# %%
risk_profile = (
    df.groupby(
        ["Contract",
         "Payment Method",
         "Internet Service"]
    )
    .agg(
        Customers=("CustomerID","count"),
        Churn_Rate=("Churn Value","mean")
    )
    .reset_index()
)

risk_profile["Churn_Rate"] = (
    risk_profile["Churn_Rate"] * 100
).round(2)

risk_profile.sort_values(
    "Churn_Rate",
    ascending=False
)
# Out:
#           Contract             Payment Method Internet Service  Customers  \
# 7   Month-to-month           Electronic check      Fiber optic       1307
# 10  Month-to-month               Mailed check      Fiber optic        201
# 1   Month-to-month  Bank transfer (automatic)      Fiber optic        327
# 4   Month-to-month    Credit card (automatic)      Fiber optic        293
# 6   Month-to-month           Electronic check              DSL        474
# 9   Month-to-month               Mailed check              DSL        367
# 3   Month-to-month    Credit card (automatic)              DSL        185
# 19        One year           Electronic check      Fiber optic        196
# 11  Month-to-month               Mailed check               No        325
# 2   Month-to-month  Bank transfer (automatic)               No         65
# 0   Month-to-month  Bank transfer (automatic)              DSL        197
# 22        One year               Mailed check      Fiber optic         36
# 8   Month-to-month           Electronic check               No         69
# 16        One year    Credit card (automatic)      Fiber optic        150
# 13        One year  Bank transfer (automatic)      Fiber optic        157
# 21        One year               Mailed check              DSL        137
# 15        One year    Credit card (automatic)              DSL        172
# 31        Two year           Electronic check      Fiber optic         92
# 18        One year           Electronic check              DSL        116
# 25        Two year  Bank transfer (automatic)      Fiber optic        162
# 5   Month-to-month    Credit card (automatic)               No         65
# 12        One year  Bank transfer (automatic)              DSL        145
# 30        Two year           Electronic check              DSL         58
# 20        One year           Electronic check               No         35
# 34        Two year               Mailed check      Fiber optic         21
# 14        One year  Bank transfer (automatic)               No         89
# 28        Two year    Credit card (automatic)      Fiber optic        154
# 27        Two year    Credit card (automatic)              DSL        237
# 24        Two year  Bank transfer (automatic)              DSL        224
# 17        One year    Credit card (automatic)               No         76
# 23        One year               Mailed check               No        164
# 29        Two year    Credit card (automatic)               No        190
# 35        Two year               Mailed check               No        252
# 26        Two year  Bank transfer (automatic)               No        178
# 33        Two year               Mailed check              DSL        109
# 32        Two year           Electronic check               No         18
#
#     Churn_Rate
# 7        60.37
# 10       50.75
# 1        45.57
# 4        41.64
# 6        40.51
# 9        30.79
# 3        27.03
# 19       26.02
# 11       20.62
# 2        20.00
# 0        19.80
# 22       19.44
# 8        18.84
# 16       15.33
# 13       14.65
# 21       10.22
# 15        9.88
# 31        9.78
# 18        9.48
# 25        9.26
# 5         9.23
# 12        7.59
# 30        6.90
# 20        5.71
# 34        4.76
# 14        4.49
# 28        3.90
# 27        2.11
# 24        1.34
# 17        1.32
# 23        1.22
# 29        1.05
# 35        0.79
# 26        0.56
# 33        0.00
# 32        0.00
